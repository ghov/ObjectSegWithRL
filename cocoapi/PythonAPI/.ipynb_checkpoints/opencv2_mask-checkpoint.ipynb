# %%
# %matplotlib inline
import cv2
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
dataDir='/media/greghovhannisyan/BackupData1/mscoco'
dataType='train2017'
annFile='%s/annotations/instances/instances_%s.json'%(dataDir,dataType)

# %%
# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=15.65s)
# creating index...
# index created!

# %%
catIds = coco.getCatIds(catNms=['person','dog','skateboard']);
imgIds = coco.getImgIds(catIds=catIds );
img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]

# %%
img_folder = '/images/train2017/'
img_id = img['id']

# %%
annIds = coco.getAnnIds(imgIds=img_id, catIds=catIds, iscrowd=None)
anns = coco.loadAnns(annIds)

# %%
# load and display instance annotations
img_folder = '/images/train2017/'
img_id = img['id']
I = io.imread(dataDir + img_folder + '000000' + str(img_id) + '.jpg')
fig = plt.figure(); plt.axis('off')
plt.imshow(I[:, :, :])
plt.show()
print(I.shape)
# Out:
# (426, 640, 3)

# %%
# load and display instance annotations
plt.imshow(I); plt.axis('off')
print(img['id'])
annIds = coco.getAnnIds(img_id, catIds=catIds, iscrowd=None)
anns = coco.loadAnns(annIds)

custom_poly = [0, 0, 700, 0, 700, 700, 0, 700]
custom_l = list()
custom_l.append(custom_poly)

# BINGO
temp_list = list()
temp_list.append(anns[0])
print(temp_list[0]['segmentation'])
#print(temp_list['segmentation']['counts'])
#temp_list[0]['segmentation'] = custom_l
coco.showAnns(temp_list)
#print(type(temp_list[0]['segmentation'][0]))
#plt.savefig('test')
# Out:
# 379520
# [[196.37, 372.96, 202.83, 366.86, 204.98, 350.37, 209.64, 326.7, 216.46, 324.55, 222.19, 326.34, 223.27, 329.21, 234.75, 324.55, 241.56, 328.85, 239.41, 347.14, 231.16, 358.61, 231.88, 361.84, 238.69, 360.77, 242.64, 356.82, 246.22, 355.39, 251.6, 331.36, 255.55, 320.24, 256.62, 328.49, 257.7, 337.46, 262.0, 337.81, 264.15, 334.59, 263.08, 327.77, 258.77, 318.09, 258.41, 307.69, 263.08, 300.52, 262.36, 284.02, 257.7, 277.57, 252.68, 271.11, 257.7, 256.77, 263.08, 243.14, 264.15, 228.79, 263.08, 228.79, 258.77, 240.63, 256.62, 251.39, 248.37, 266.81, 247.3, 269.32, 237.26, 270.75, 233.67, 270.75, 224.35, 277.21, 222.91, 277.21, 224.35, 264.66, 220.04, 265.37, 215.74, 271.11, 210.36, 268.96, 210.36, 262.86, 207.13, 259.64, 201.39, 263.22, 199.96, 269.68, 190.64, 279.72, 189.92, 287.97, 185.97, 292.27, 185.97, 297.29, 188.84, 298.37, 191.35, 297.29, 192.07, 300.52, 191.35, 304.1, 195.3, 306.61, 200.32, 306.26, 198.53, 317.73, 198.53, 324.19, 200.68, 330.28, 197.45, 341.04, 197.45, 357.9, 197.45, 361.48, 187.77, 369.01, 187.05, 372.96, 190.99, 375.11, 195.66, 374.75]]

# %%
a = cv2.imread(dataDir + img_folder + '000000' + str(img_id) + '.jpg')
b = coco.annToMask(anns[0])
res = cv2.bitwise_not(a,a,mask = b)

# %%
cv2.imshow('img', res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#print(temp_list[0]['image_id'])
mask_as_arr = coco.annToMask(anns[0])
#mask_as_arr = coco.annToMask(temp_list[0])
#np.sum(coco.annToMask(temp_list[0]))

# %%
plt.imshow(I, cmap='gray')
plt.axis('off')
a = plt.imshow(mask_as_arr, cmap='tab20c', alpha=0.5).get_array()
plt.savefig('test')
print(np.unique(a))
io.imshow(a)
# Out:
# [0 1]
# /usr/local/lib/python3.5/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:77: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
from PIL import Image

img = Image.fromarray(coco.annToMask(temp_list[0]), '1')
img.save('my.jpg')
img.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80f965b9baa4> in <module>()
#       1 from PIL import Image
#       2
# ----> 3 img = Image.fromarray(coco.annToMask(temp_list[0]), '1')
#       4 img.save('my.jpg')
#       5 img.show()
#
# NameError: name 'coco' is not defined
